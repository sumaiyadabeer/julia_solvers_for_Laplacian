# %%
import numpy as np

import matplotlib.pyplot as plt

import scipy
import time

# %%
Lsolve_x = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/wikipedia_link_bug_b_50_Qby2.out", dtype=float)
Lsolve_time =  Lsolve_x[0]
Lsolve_residual =  Lsolve_x[1]
Lsolve_x = Lsolve_x[2:]

# Lsolve_x = Lsolve_x/1.6
# len(Lsolve_x)
# Lsolve_x = Lsolve_x - Lsolve_x[14028]

# %%
Lsolve_x_eta_c = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/wikipedia_link_bug_b_50_b_1.out", dtype=float)
Lsolve_time_eta_c =  Lsolve_x_eta_c[0]
Lsolve_residual_eta_c =  Lsolve_x_eta_c[1]
Lsolve_x_eta_c = Lsolve_x_eta_c[2:]
Lsolve_x_eta_c = Lsolve_x_eta_c/1280
# len(Lsolve_x)

# %%
Chol_23_x = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b50_Chol_23", dtype=float)
Chol_23_time =  Chol_23_x[0]
Chol_23_residual =  Chol_23_x[1]
Chol_23_x = Chol_23_x[2:]
Chol_23_x = Chol_23_x/128
len(Chol_23_x)
Chol_23_x[14028]
# Out:
# 0.0

# %%
# time and residual

# print("Lsolve time: ", Lsolve_time_eta_c, "\t Lsolve residual: ", Lsolve_residual_eta_c) 
print("Lsolve time: ", Lsolve_time, "\t Lsolve residual: ", Lsolve_residual) 
print("Chol23 time: ", Chol_23_time, "\t Chol23 residual: ", Chol_23_residual)
# Out:
# Lsolve time:  20.0196 	 Lsolve residual:  5.111025106337043
# Chol23 time:  2.3600969314575195 	 Chol23 residual:  2.3566473901421393e-14

# %%
# sink_neighbours = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/web_bug_sink_neighbours.txt", dtype=float)
# sink_neighbours = -sink_neighbours

# for i in range(len(sink_neighbours)):
#     if sink_neighbours[i] < 0:
#         sink_neighbours[i] = 0
#     elif sink_neighbours[i]:
#         sink_neighbours[i] = Lsolve_x[i]
#     else:
#         sink_neighbours[i] = 0.000125

# %%
b = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/bug_50_b.txt", dtype=int)
# is_source.sort()
is_source = []
counter = 0
for i in b:
    counter = counter + 1
    if i < 0:
        is_source.append(np.NaN)
    if i > 0:
        is_source.append(Lsolve_x_eta_c[counter])
    if i == 0:
        is_source.append(np.NaN)
    # print(i)
# print(is_source)

# %%
# ?plt.hist;
# Out:
# Object `plt.hist;` not found.

# %%
# Degree distribution (identifying the low degree vertices)
degree_list = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/wikibug_degrees.txt", dtype=int)

degree_list[degree_list == 27740] = 0

plt.hist(degree_list,bins = 175)
plt.xlabel("Degree")
plt.ylabel("Frequency")
plt.title("Histgram for degrees (after removing the highest degree node (27740)) (bar width = 10) ")
print(len(degree_list))
# Out:
# 14229

# %%
degree_2 = []
# degree_4 = []
counter = -1
for i in degree_list:
    counter = counter + 1
    if i <= 55: # Isolated vertices
        degree_2.append(Lsolve_x[counter])
    else:
        degree_2.append(np.NaN)
    # print(i)
# print(is_source)

# %%
# 14120 degrees

neighbour = []

degree_list_max = np.loadtxt("/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/degree_14126.txt", dtype=float)
counter = -1
for i in degree_list_max:
    counter = counter + 1
    if abs(i) > 0.0: # Isolated vertices
        neighbour.append(Lsolve_x[counter])
    else:
        neighbour.append(np.NaN)

# %%
# plt.scatter(list(range(0, len(list(Lsolve_x_eta_c)))), list(Lsolve_x_eta_c), c = "purple", label  = "Lsolve_eta_c", alpha=0.1)
plt.scatter(list(range(0, len(list(Chol_23_x)))), list(Chol_23_x), c = "blue", label = "Chol23", alpha=0.1)
plt.scatter(list(range(0, len(list(Lsolve_x)-1000))), list(Lsolve_x[:-1000]), c = "red", label  = "Lsolve", alpha=0.1)
# plt.scatter(list(range(0, len(list(is_source)))), list(is_source), c = "green", label  = "is_source", alpha=0.1)
 
    # To show the plot
plt.xlabel("node")
plt.ylabel("x")
plt.title("Lx=b")
plt.legend()
print("\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # plt.scatter(list(range(0, len(list(Lsolve_x_eta_c)))), list(Lsolve_x_eta_c), c = "purple", label  = "Lsolve_eta_c", alpha=0.1)
#       2 plt.scatter(list(range(0, len(list(Chol_23_x)))), list(Chol_23_x), c = "blue", label = "Chol23", alpha=0.1)
# ----> 3 plt.scatter(list(range(0, len(list(Lsolve_x)-1000))), list(Lsolve_x[:-1000]), c = "red", label  = "Lsolve", alpha=0.1)
#       4 # plt.scatter(list(range(0, len(list(is_source)))), list(is_source), c = "green", label  = "is_source", alpha=0.1)
#       5
#       6     # To show the plot
#       7 plt.xlabel("node")
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
a
# Out:
# <14266x14266 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6766950 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### these values are to do the scaling analysis of cycle graph of size 32

# %%
# node = [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384 ]
# times= [ 0.007953405380249023, 0.011931657791137695, 0.014152765274047852, 0.02232050895690918, 0.02371525764465332, 0.025827646255493164, 0.03429222106933594, 0.03286433219909668
# , 0.1994631290435791, 0.2776668071746826]

# %%
# plt.loglog(node, times)

# %%
# making x[sink] = 0 by adding a value
x=list(x)
x_sink_zero = []
for i in x:
    x_sink_zero.append(i+abs(x[sink_index]))

# %%
x_sink_zero
#  (\beta = 0.0625)for all source= [0.512461997518161, 0.5065619963141459, 0.49661849286960547, 0.4826276703839043, 0.46455790916138345, 0.4424395937829611, 0.4162792324888245, 0.3860400307698299, 0.3518115772103654, 0.31359803014765464, 0.27128454197939733, 0.22504982204895038, 0.17493521293041228, 0.12085387500868972, 0.0625406695768404, 0.0, 0.06266680202831687, 0.12110651281045079, 0.17531534796564763, 0.22556381449080407, 0.2719314135611737, 0.3143785075756812, 0.35274847386957264, 0.3871055949997903, 0.4174364605931168, 0.44371591167260815, 0.4657526999480026, 0.48342202446349847, 0.49667461635756827, 0.5062105754774081, 0.5121326504674586, 0.51432974065766]
# Out:
# [0.5846592611385159,
#  0.585220038773583,
#  0.5846674465215638,
#  0.5846580410644315,
#  0.5846571685807952,
#  0.5846597172284982,
#  0.5843180931644567,
#  0.5846585393397195,
#  0.5843216470134428,
#  0.5846463881523052,
#  0.5852439350763188,
#  0.5848896444680128,
#  0.5852183185584472,
#  0.58431405581589,
#  0.5846601166317278,
#  0.5846465887385253,
#  0.5848940137305373,
#  0.5846570825397827,
#  0.5846576699438424,
#  0.5848830888493292,
#  0.5846560392370923,
#  0.5843170173999557,
#  0.5843268950717173,
#  0.5848915268494177,
#  0.5846489009329111,
#  0.5852292412583319,
#  0.5843235593844796,
#  0.584893727182101,
#  0.584653271124876,
#  0.5843141687930542,
#  0.5846643242533502,
#  0.5843164917031468,
#  0.5852233325326228,
#  0.5846475925125924,
#  0.5843290938067424,
#  0.5843211320671331,
#  0.5852152384547952,
#  0.5846563492941619,
#  0.5843298388206241,
#  0.5852049597512768,
#  0.5846492329310599,
#  0.5846477869313419,
#  0.5852302998944965,
#  0.5846534130861415,
#  0.5843137344457018,
#  0.5846532204715987,
#  0.5843145009841691,
#  0.5846494194653447,
#  0.5852357275581748,
#  0.5852203473510933,
#  0.5852127925473877,
#  0.5846541695075239,
#  0.5846601452715608,
#  0.5843253998169147,
#  0.5846509452782764,
#  0.584315882249406,
#  0.5852286887433089,
#  0.5852142882850765,
#  0.5846546754221381,
#  0.5843201901438465,
#  0.584654321736216,
#  0.5846601842748885,
#  0.584316519416476,
#  0.5852327525776794,
#  0.5843239780970728,
#  0.5846522597704787,
#  0.584318548358761,
#  0.584314128895032,
#  0.5843187630389548,
#  0.584647504275177,
#  0.5843140539859494,
#  0.5846532267259978,
#  0.5852235419024028,
#  0.5843209990160825,
#  0.5843227816172107,
#  0.5846594563940334,
#  0.584314279714887,
#  0.5846491321024477,
#  0.5846601562454266,
#  0.5846455314795208,
#  0.584656884374289,
#  0.5846487065619357,
#  0.5843215576493141,
#  0.5852210140980583,
#  0.5843141196924346,
#  0.5843303976174328,
#  0.5846528439957965,
#  0.5843326943153403,
#  0.5843152930823888,
#  0.5846553292413484,
#  0.5846561444451944,
#  0.5846650245799354,
#  0.584326342591719,
#  0.584319920948627,
#  0.5843320138652366,
#  0.5843217690943457,
#  0.5846485714599013,
#  0.5846603973433103,
#  0.585223162650243,
#  0.5843190415357596,
#  0.584657748374118,
#  0.5846643099541641,
#  0.5846597268767357,
#  0.5843150762563804,
#  0.5848837169717618,
#  0.5846618329547923,
#  0.5843152081657427,
#  0.5848878001737139,
#  0.5848756581881633,
#  0.5852318348467728,
#  0.5843341387304926,
#  0.5849042122170371,
#  0.5846562542767736,
#  0.5852206309157808,
#  0.58489134150236,
#  0.585242045879853,
#  0.5846594627257555,
#  0.5843177160903664,
#  0.5846495312070639,
#  0.5848903805604009,
#  0.5843272279952485,
#  0.5846627537246281,
#  0.5843329214059431,
#  0.5852153610797284,
#  0.5846632767388682,
#  0.5843204988382673,
#  0.5852172956978215,
#  0.5851988072689112,
#  0.5846569508942008,
#  0.5846590716566882,
#  0.5843237339826255,
#  0.5843209351304116,
#  0.5846470509536851,
#  0.5843258803168377,
#  0.5848890557826031,
#  0.5852469639149155,
#  0.5846561618544941,
#  0.5846577383425309,
#  0.5843179578852947,
#  0.5846580507995122,
#  0.58465002074517,
#  0.5846602009804921,
#  0.5846503728218547,
#  0.5846593791260419,
#  0.5843163438740843,
#  0.5846544172204895,
#  0.5848897271230985,
#  0.5846540496646253,
#  0.5846463566377835,
#  0.5846475581983785,
#  0.5846617786433882,
#  0.5846489634781394,
#  0.5843367213090075,
#  0.5846603055904821,
#  0.5848872939531059,
#  0.5846525455664244,
#  0.5846593194027349,
#  0.5846500840804096,
#  0.5846561335538119,
#  0.5846525464559335,
#  0.5852347576242357,
#  0.5846588603005847,
#  0.5843212607621765,
#  0.5852371370075055,
#  0.5852238125194307,
#  0.5846604260729318,
#  0.5846564243377628,
#  0.5846523307535954,
#  0.5846501552355039,
#  0.5843220413837905,
#  0.5843082073710212,
#  0.5846519343567623,
#  0.5843341960138263,
#  0.5843120230106464,
#  0.5846406536760308,
#  0.5843172990067542,
#  0.5846431643521831,
#  0.5846576140999432,
#  0.584659832987037,
#  0.5848995500948884,
#  0.5846605259991066,
#  0.5852371149067217,
#  0.5843218538123064,
#  0.5846492303595026,
#  0.5846572778227055,
#  0.5852274124052659,
#  0.5848980368958028,
#  0.5846566071867909,
#  0.5846513218772099,
#  0.5846485389063595,
#  0.5843306668138368,
#  0.5843223957819768,
#  0.5849061992290614,
#  0.5846580367006261,
#  0.5846418839995499,
#  0.5846568530251003,
#  0.584325561287313,
#  0.5846544353467547,
#  0.5846583324508621,
#  0.5846560400149189,
#  0.5843162538204847,
#  0.584651476534222,
#  0.5846510731144311,
#  0.5846529329329867,
#  0.5843162210757593,
#  0.5843195282513255,
#  0.5846532724053329,
#  0.5843301023510402,
#  0.5843147659939829,
#  0.5843232390018621,
#  0.5846480609919493,
#  0.5846457472692828,
#  0.5852226883210171,
#  0.5843142754094709,
#  0.5846522180384822,
#  0.5848925869321121,
#  0.5842992694441221,
#  0.5843206182279624,
#  0.5846652713769775,
#  0.5848906447776349,
#  0.5846587229125995,
#  0.5846607026449988,
#  0.5846579160981272,
#  0.5849073139605366,
#  0.5843314283232823,
#  0.5852578471488262,
#  0.5846545022638667,
#  0.5843301925916219,
#  0.5846461761037351,
#  0.5843290791810696,
#  0.5852265193756705,
#  0.5846603158475727,
#  0.5846595205370386,
#  0.584641345252498,
#  0.5846464064990191,
#  0.5843263181001513,
#  0.5852219200214201,
#  0.5846520981265986,
#  0.5846526241493532,
#  0.5846543699474026,
#  0.5846409519291624,
#  0.5843300484908762,
#  0.5843142062488348,
#  0.5843240184939881,
#  0.5846423304773708,
#  0.5846592890322877,
#  0.5846550220394461,
#  0.5846514514834573,
#  0.5843259544286822,
#  0.5848979126551367,
#  0.5846580947635971,
#  0.5852452784159333,
#  0.5843140956189087,
#  0.5846587024528727,
#  0.5846475415438873,
#  0.5846569240320294,
#  0.5846472780856661,
#  0.5843155507563375,
#  0.5846554588180531,
#  0.5843326578545591,
#  0.5843165674215263,
#  0.5846462477020372,
#  0.5846565111092004,
#  0.5852169321867424,
#  0.5846589378654845,
#  0.584658443149553,
#  0.5846477721923463,
#  0.58465391560896,
#  0.5846557735438384,
#  0.5843350565704553,
#  0.5852163030646985,
#  0.5843260606637485,
#  0.5843088434349261,
#  0.5843189475031446,
#  0.5843174853514074,
#  0.584658779245118,
#  0.5846580536086381,
#  0.584316176807604,
#  0.5846556984732355,
#  0.5843308496112211,
#  0.584895043587708,
#  0.5852172888325652,
#  0.585232000579337,
#  0.5848927077981821,
#  0.5843316506870756,
#  0.5846547366462591,
#  0.5848880941680784,
#  0.5846556301583181,
#  0.5843204304840109,
#  0.5846596771447036,
#  0.5846620148850449,
#  0.5843215195719754,
#  0.5843142626511666,
#  0.5843253416187105,
#  0.5846519654703902,
#  0.5843257716831204,
#  0.5846489044185423,
#  0.5848914263819424,
#  0.5852392572210361,
#  0.5843205415359055,
#  0.5846548570177991,
#  0.5843226773687668,
#  0.5846460127272605,
#  0.5846439524303818,
#  0.5848808874470368,
#  0.5846487490074624,
#  0.5843240966829237,
#  0.5846381974696212,
#  0.5843057887056472,
#  0.5843290843272853,
#  0.5846483753761708,
#  0.5846544932352431,
#  0.5843238406378813,
#  0.5846491219192029,
#  0.5843198806185299,
#  0.5852024378562883,
#  0.5846559032596521,
#  0.5846591694676125,
#  0.5846644870427669,
#  0.5846449126269321,
#  0.5846458850727437,
#  0.5843215255276091,
#  0.5846542039447025,
#  0.5843028415929852,
#  0.5843199753343947,
#  0.5846624585840555,
#  0.5846584914836757,
#  0.5852297477360261,
#  0.5843228789185105,
#  0.5846547043011197,
#  0.5843280627171069,
#  0.5843351979711776,
#  0.5846503543807783,
#  0.5846512304488075,
#  0.584898104729406,
#  0.5846541815198082,
#  0.5846604132764446,
#  0.5846509609205284,
#  0.5843190807377857,
#  0.5843317681102821,
#  0.5848915854192318,
#  0.5843260806679075,
#  0.5846495970759302,
#  0.5852336154871972,
#  0.5846531160761383,
#  0.5852229929988502,
#  0.5846525457202343,
#  0.5843205705217239,
#  0.5848951860769537,
#  0.5846580775283209,
#  0.5846607452060429,
#  0.584325785562713,
#  0.5846523475312814,
#  0.5852314370683481,
#  0.584321153094903,
#  0.5846544483420405,
#  0.5849060297500842,
#  0.585227466053089,
#  0.5846472403156342,
#  0.5846580644973759,
#  0.5846544229048382,
#  0.5846579212359087,
#  0.584331609392825,
#  0.5843102530072277,
#  0.5846443184122638,
#  0.5843059736475145,
#  0.5846535010861788,
#  0.5846616947541388,
#  0.5848882710714428,
#  0.5848737390693158,
#  0.5846555784173662,
#  0.5843264407393249,
#  0.5852105831951787,
#  0.5846535015486302,
#  0.584658904043713,
#  0.5846606040820251,
#  0.5846538792564764,
#  0.5846509256750189,
#  0.584651525422171,
#  0.5852183468873403,
#  0.5846515925151681,
#  0.5846521467494007,
#  0.5843197990672027,
#  0.5843288681427791,
#  0.5843251207721413,
#  0.5849048726085196,
#  0.584895711924282,
#  0.5852165044472536,
#  0.5848875733479018,
#  0.584324602184696,
#  0.584654935360174,
#  0.5846577677049238,
#  0.5846469385640655,
#  0.5843223761494285,
#  0.5843218788856418,
#  0.5849028913577976,
#  0.5846415420384558,
#  0.5846506909635868,
#  0.5843238796216036,
#  0.5843127939324567,
#  0.584650724312969,
#  0.5843322113209092,
#  0.5846514975791418,
#  0.5852324323645192,
#  0.5846568370803099,
#  0.5848905509263357,
#  0.5843295465976092,
#  0.5846556030310295,
#  0.5848900348861021,
#  0.5846580493431265,
#  0.5843252073577249,
#  0.5843341182153442,
#  0.5846577543324688,
#  0.5848919808434304,
#  0.5843259569344254,
#  0.5846528826507904,
#  0.5846602859060834,
#  0.5846494866419095,
#  0.5852133373839015,
#  0.5846445342264613,
#  0.5852398994493047,
#  0.585220091680839,
#  0.5843303791170407,
#  0.5848930680417693,
#  0.5843254789905915,
#  0.5843104581217271,
#  0.5843216739702013,
#  0.5846604455681007,
#  0.5843224628107855,
#  0.5846581352674941,
#  0.584897408324256,
#  0.584894756265055,
#  0.5843271122755251,
#  0.584659900074283,
#  0.5846549013229465,
#  0.5843082700821062,
#  0.5846519190211786,
#  0.584658024402438,
#  0.5846587146825303,
#  0.5846616532468087,
#  0.5848875502916123,
#  0.5846585616412977,
#  0.5843212580456243,
#  0.5843155606653877,
#  0.5846591658181073,
#  0.5843081690808583,
#  0.5843283293471474,
#  0.5843360207006222,
#  0.5846543019853029,
#  0.5846596222089971,
#  0.5848937435664736,
#  0.5846603487583306,
#  0.5846588787807688,
#  0.5843362241854563,
#  0.5846592450422516,
#  0.5843222728825175,
#  0.5843288684359835,
#  0.5848950706912446,
#  0.5852163912702659,
#  0.5843210128124148,
#  0.5843125788545307,
#  0.5846489453272291,
#  0.585222608971897,
#  0.5852289381215438,
#  0.5848960313496482,
#  0.5852361378992904,
#  0.5843187326595001,
#  0.5843224951254166,
#  0.5848951968498656,
#  0.5852188902717764,
#  0.5849031940490831,
#  0.5848988059385656,
#  0.5852155288873709,
#  0.5846545561463666,
#  0.5843215414712066,
#  0.5852218034684948,
#  0.5843099730692896,
#  0.5843128578287281,
#  0.5846560321481364,
#  0.5843346941946744,
#  0.5846570326850629,
#  0.5843319172261568,
#  0.5846471168643412,
#  0.5846525299743951,
#  0.5848937087171122,
#  0.5843121466769463,
#  0.5846553892838715,
#  0.5843326005102424,
#  0.5846547669250054,
#  0.5846581778480372,
#  0.5852344016235266,
#  0.5843263822262199,
#  0.5846583400874512,
#  0.5848862724675775,
#  0.5846522376725831,
#  0.5848891279521958,
#  0.5846634692445565,
#  0.5852396435587779,
#  0.5846594435863955,
#  0.5843125206214898,
#  0.5852281222995985,
#  0.5843104123773663,
#  0.5846617108278191,
#  0.5843117980341465,
#  0.5846591080561199,
#  0.5846505031014753,
#  0.5852205519715189,
#  0.5843169958927703,
#  0.5843269041867895,
#  0.5846546487313987,
#  0.5843231818196607,
#  0.5843185760464095,
#  0.5846526077212041,
#  0.5843106115824501,
#  0.584894836489899,
#  0.5846502316721062,
#  0.5843242956221747,
#  0.5846555797877978,
#  0.5846607489856417,
#  0.5846475347456731,
#  0.5843295459439928,
#  0.5843210062591846,
#  0.5846542751820609,
#  0.5848859403879113,
#  0.5843194450102918,
#  0.5843315029063761,
#  0.5843231190224866,
#  0.584655447729748,
#  0.5843223301221165,
#  0.5852296152601326,
#  0.5852397607159792,
#  0.585216839443173,
#  0.5848908533276281,
#  0.5846458494064071,
#  0.5846570418307248,
#  0.5843220313182883,
#  0.5843200889650013,
#  0.5843280543803794,
#  0.5852390148017184,
#  0.585209557053848,
#  0.5846568912024663,
#  0.5846523075545966,
#  0.5846551697202674,
#  0.5846505012014974,
#  0.5848979806940362,
#  0.5846593196026374,
#  0.5843218906995452,
#  0.5843257626284533,
#  0.5848929103279716,
#  0.5846561511932707,
#  0.5846551086143892,
#  0.5843135006025858,
#  0.5846499858363702,
#  0.5846456134466146,
#  0.5846524792099119,
#  0.5843117555041132,
#  0.58432731653259,
#  0.5852117741163836,
#  0.585230733790664,
#  0.5852327178604902,
#  0.5846681459864161,
#  0.5846593274411219,
#  0.5851924093563274,
#  0.5846590215382725,
#  0.5843215582976317,
#  0.5849088298212122,
#  0.5852308219388234,
#  0.5846574911221454,
#  0.5843266370192888,
#  0.5848974411360144,
#  0.5843237906424552,
#  0.5846464618989322,
#  0.5846425436393587,
#  0.5846556788977915,
#  0.5852259162152138,
#  0.5843323276097405,
#  0.5852338983595837,
#  0.5843187692025655,
#  0.5846559372858874,
#  0.5843367766547404,
#  0.5846536448123925,
#  0.5849018122549103,
#  0.5846522777403499,
#  0.58464474054633,
#  0.5843140154823416,
#  0.5846554055284335,
#  0.5843243803426977,
#  0.5852211263508798,
#  0.5846604187223363,
#  0.5843112369748096,
#  0.5843189628259314,
#  0.5852199698986775,
#  0.5843353625467854,
#  0.5846539503149721,
#  0.5846621327457776,
#  0.5846594887234939,
#  0.5852474383897227,
#  0.5846454004955978,
#  0.584894500930377,
#  0.5846537330267774,
#  0.5846529408786613,
#  0.5846617909950375,
#  0.5849053091905659,
#  0.585245775863017,
#  0.5846554931244892,
#  0.5846563425403241,
#  0.5852197288550726,
#  0.5846552385620108,
#  0.5846587678648255,
#  0.584326583435845,
#  0.5843205838953834,
#  0.5846510063752396,
#  0.5843122436585947,
#  0.5848984959419229,
#  0.5848911968183276,
#  0.584880592991872,
#  0.5843247076172285,
#  0.584663631951952,
#  0.5849008823609663,
#  0.5848866903285709,
#  0.584310314046607,
#  0.5846606613257199,
#  0.5846613291498377,
#  0.5852211509570316,
#  0.584890245077389,
#  0.584649030367327,
#  0.5846577233559851,
#  0.5852167733209834,
#  0.584650871279682,
#  0.5843228355526222,
#  0.5846563950375986,
#  0.5848915088173329,
#  0.5846591717279824,
#  0.5843339211660135,
#  0.5848884596266253,
#  0.5852218021648984,
#  0.5846594174288922,
#  0.5848926596958983,
#  0.5843264855514367,
#  0.5846595911259153,
#  0.5846602533826406,
#  0.5846620781425065,
#  0.5852063370196027,
#  0.5846552155570655,
#  0.5846650283873098,
#  0.5843189641381071,
#  0.5843355167163302,
#  0.5846500280906809,
#  0.5843226738035229,
#  0.5848947749712143,
#  0.5852248131097045,
#  0.5852180663673414,
#  0.5846568186423837,
#  0.5848914091795427,
#  0.5846555812358796,
#  0.58465801746941,
#  0.5843145840029611,
#  0.5846543307627481,
#  0.5846482452523865,
#  0.5846511930119601,
#  0.5846550011047783,
#  0.5848899140825482,
#  0.5846637478646157,
#  0.5843083166228089,
#  0.5843290573999471,
#  0.5843253265734268,
#  0.5846602185719944,
#  0.584657111165145,
#  0.5843313402253173,
#  0.5852105122268986,
#  0.5848935665700047,
#  0.5843169859075343,
#  0.5846585283567062,
#  0.5843281877498225,
#  0.5843185003916798,
#  0.5846609100560555,
#  0.584315012025738,
#  0.584887180748542,
#  0.5846555827635087,
#  0.5852360378631838,
#  0.5843214788275459,
#  0.5846713510587527,
#  0.5852185995277984,
#  0.5846404591725752,
#  0.5846530728835645,
#  0.584318938484489,
#  0.5846599630740766,
#  0.5846555185358944,
#  0.5846574023206172,
#  0.5852153582767504,
#  0.5843125102476392,
#  0.5843170019585749,
#  0.585221717634877,
#  0.5852268634425987,
#  0.5846630978062836,
#  0.5843186017128151,
#  0.5846481928738673,
#  0.5852235672367463,
#  0.5843195444980642,
#  0.5846544079123868,
#  0.5852171913678166,
#  0.5848982626946991,
#  0.5846493318449575,
#  0.5846567598218931,
#  0.5843354849390745,
#  0.5846620621408928,
#  0.5846576261827771,
#  0.5848853423770738,
#  0.5846453421885192,
#  0.5846513812819709,
#  0.5846512116762786,
#  0.5852241321470564,
#  0.5846572261899103,
#  0.58466204955691,
#  0.5843104012266881,
#  0.5843180165672954,
#  0.5843274158755023,
#  0.584657759051915,
#  0.5849005885570314,
#  0.584651151016542,
#  0.584320821879137,
#  0.5852462745128997,
#  0.58464843231414,
#  0.5852285022469899,
#  0.5852168622700913,
#  0.5846485748683972,
#  0.5846480647555499,
#  0.5852285333085001,
#  0.5846598172431611,
#  0.5846561104022479,
#  0.5846587359170322,
#  0.5843350216098446,
#  0.5843206659064532,
#  0.5848835226679684,
#  0.5846577709316093,
#  0.5843176911686316,
#  0.5846533823946597,
#  0.5852169501663681,
#  0.5843214767282393,
#  0.5852393576297695,
#  0.5846554253470406,
#  0.5843023516379027,
#  0.5848844022576202,
#  0.5843193288790465,
#  0.5846584605440366,
#  0.5846550861729972,
#  0.5846590594360146,
#  0.584650119200456,
#  0.5846454679678704,
#  0.58431766053806,
#  0.5852286084616652,
#  0.5852235864013918,
#  0.5846412367988703,
#  0.5852125521712945,
#  0.5843231905958839,
#  0.5852363820657466,
#  0.58463950698128,
#  0.5852239220620621,
#  0.5843243810985045,
#  0.5852238067238617,
#  0.5848906389789155,
#  0.5846642999838122,
#  0.5846532862075574,
#  0.5846546914983841,
#  0.5852237389398948,
#  0.5846524379188365,
#  0.5846536267608767,
#  0.5852286077778411,
#  0.5846606993294455,
#  0.585211547321403,
#  0.5846552916642358,
#  0.5852309890197464,
#  0.584658727216111,
#  0.5843179687056715,
#  0.5846423507653592,
#  0.5852195614093048,
#  0.5848934935532354,
#  0.5846641663474673,
#  0.5843213395197902,
#  0.5848947372377808,
#  0.5846530966050286,
#  0.5846515193273215,
#  0.5843071382082657,
#  0.5846574727029402,
#  0.5843213367458208,
#  0.5846530141129324,
#  0.5846596506689679,
#  0.5843205725484023,
#  0.5848894688310309,
#  0.5843194887634252,
#  0.5846510645501156,
#  0.584655791004075,
#  0.584647354077206,
#  0.5846536165803969,
#  0.5843227886961119,
#  0.5846481162334484,
#  0.5846548709090585,
#  0.5848885360498516,
#  0.5846577442537784,
#  0.5843278447142248,
#  0.5846556460242519,
#  0.5843243218702581,
#  0.5843183207693816,
#  0.5852204322383783,
#  0.5843201339423265,
#  0.5843191269088374,
#  0.5846570947325801,
#  0.5846594510539327,
#  0.5843291317982405,
#  0.5846525685547728,
#  0.5843210955146418,
#  0.584654063346414,
#  0.5843292054617173,
#  0.5846526871679304,
#  0.5846588141070285,
#  0.5846577148176566,
#  0.584649784804444,
#  0.584660403451244,
#  0.5846504490624138,
#  0.584655135570317,
#  0.5846516116168852,
#  0.584655580579089,
#  0.584322181893442,
#  0.5846436123515932,
#  0.5843205960095131,
#  0.5846521523465519,
#  0.5846608960950875,
#  0.5852141771495563,
#  0.5846407606249349,
#  0.584656694027708,
#  0.5846596329004928,
#  0.5843201447761539,
#  0.5846583630174746,
#  0.5843262606208051,
#  0.5852137507519964,
#  0.585218755739859,
#  0.5848801032431701,
#  0.5852288460197028,
#  0.5846562017602195,
#  0.584889153228219,
#  0.5846471304621464,
#  0.5843171574100281,
#  0.5846544165122295,
#  0.5843288713633805,
#  0.5846628102059123,
#  0.5846525698726036,
#  0.5846525305396344,
#  0.5846455971211035,
#  0.5848847058161621,
#  0.5846615442195081,
#  0.5846549722899275,
#  0.5846613205094001,
#  0.5852375860083184,
#  0.5846606482495368,
#  0.5846586833937121,
#  0.5843249904134868,
#  0.5843193422333306,
#  0.5843115473701098,
#  0.5846559273526726,
#  0.5852286756071052,
#  0.5843290308046988,
#  0.5843215519801838,
#  0.5846651480404429,
#  0.5852269682196336,
#  0.5852170251978847,
#  0.585231503692773,
#  0.5846433338879168,
#  0.5843194655323218,
#  0.5846653465851952,
#  0.5846518674781954,
#  0.5843198164265879,
#  0.5846493126344816,
#  0.5846547385173055,
#  0.5843115877609422,
#  0.5846513727514219,
#  0.5843199657687601,
#  0.5846549056368887,
#  0.5846497460361174,
#  0.5848834975534634,
#  0.5846500735176609,
#  0.5848906357078298,
#  0.5846509841470953,
#  0.5843195769299833,
#  0.5852421885178324,
#  0.5846522168502564,
#  0.5843138281933196,
#  0.5843153715013206,
#  0.5849073492016033,
#  0.584651737479123,
#  0.5852202021931802,
#  0.585218484951724,
#  0.584310771883225,
#  0.5843293725729866,
#  0.5846484536232873,
#  0.5846546405352023,
#  0.5846570795903441,
#  0.5846548390506324,
#  0.5846505332896987,
#  0.5843196851917848,
#  0.5843118349635975,
#  0.5846505913214738,
#  0.5846602149014656,
#  0.5846480545668178,
#  0.5846570088659482,
#  0.5843102340367922,
#  0.5843224306650788,
#  0.5846518606047899,
#  0.5843194152500888,
#  0.5843200893307027,
#  0.5843214820321383,
#  0.5846493019006066,
#  0.5843160915871045,
#  0.5846510027429789,
#  0.5843255017437433,
#  0.5846470124172224,
#  0.5843329691919276,
#  0.5846610342525481,
#  0.5852276559701753,
#  0.5846489569212656,
#  0.5846443576287066,
#  0.58465774980091,
#  0.5848988344467859,
#  0.584647898581966,
#  0.5852275654755488,
#  0.584652022898454,
#  0.5848937700468833,
#  0.5843240106430062,
#  0.5843332714979397,
#  0.5843270560417018,
#  0.5846475571889669,
#  0.5843081619739188,
#  0.5846660805024915,
#  0.585233465638293,
#  0.5846507500896717,
#  0.5846480700547462,
#  0.5848915240362053,
#  0.5843117487937577,
#  0.5843117067157695,
#  0.5843235570679677,
#  0.5852225554916055,
#  0.5852267383935995,
#  0.5846620637943869,
#  0.5843129737790943,
#  0.5843296200737722,
#  0.5846541488801812,
#  0.5846432993885676,
#  0.5848939700458331,
#  0.5846585448654451,
#  0.5852165019066357,
#  0.5849009442969125,
#  0.5846543681297874,
#  0.584646403640874,
#  0.5843233727081674,
#  0.5848894320247598,
#  0.5846550156072099,
#  0.5846597476856504,
#  0.5843249098310569,
#  0.5852118169913215,
#  0.5846495075793953,
#  0.5846509943956979,
#  0.584898655928324,
#  0.5852102492021379,
#  0.5846610437768376,
#  0.5848890474968306,
#  0.584316656846728,
#  0.5852269868107013,
#  0.5843147482202339,
#  0.5843205136764064,
#  0.5846583993756175,
#  0.5843090817864173,
#  0.5846519552590983,
#  0.5846581412502638,
#  0.584321656624416,
#  0.5846486176359975,
#  0.5846528606613945,
#  0.5846432599126662,
#  0.5843246915057538,
#  0.5843273883700785,
#  0.5843438106336311,
#  0.5846569246353365,
#  0.5852239061188521,
#  0.5846584553919933,
#  0.5846445612065839,
#  0.585240018993832,
#  0.5843292902307682,
#  0.5848926468152301,
#  0.5843016476516744,
#  0.58431577821499,
#  0.5843246573916523,
#  0.5848871564080733,
#  0.5852225913023529,
#  0.5843247876745633,
#  0.5852374168787867,
#  0.5846576301000063,
#  0.5849027880148107,
#  0.5846531884698831,
#  0.584893109848299,
#  0.5846451579829937,
#  0.5843219490496914,
#  0.5848869071676079,
#  ...]

# %%
#x from cudasolver simulation
x_simulation_complete_32 = [0.007924,0.015802,0.008004,0.008087,0.007825,0.007962,0.008077,0.007914,0.007971,0.007913,0.007905,0.008019,0.007934,0.007883,0.008061,0.000000,0.007845,0.008041,0.007876,0.008016,0.007931,0.008130,0.007924,0.007976,0.007794,0.007925,0.007847,0.007874,0.007943,0.007863,0.007845,0.007920]

# %%
x_sink_zero = [0.512461997518161, 0.5065619963141459, 0.49661849286960547, 0.4826276703839043, 0.46455790916138345, 0.4424395937829611, 0.4162792324888245, 0.3860400307698299, 0.3518115772103654, 0.31359803014765464, 0.27128454197939733, 0.22504982204895038, 0.17493521293041228, 0.12085387500868972, 0.0625406695768404, 0.0, 0.06266680202831687, 0.12110651281045079, 0.17531534796564763, 0.22556381449080407, 0.2719314135611737, 0.3143785075756812, 0.35274847386957264, 0.3871055949997903, 0.4174364605931168, 0.44371591167260815, 0.4657526999480026, 0.48342202446349847, 0.49667461635756827, 0.5062105754774081, 0.5121326504674586, 0.51432974065766]
x_simulation_cycle_32_allsource_30k = [0.429400,0.423833,0.414867,0.410667,0.395450,0.369267,0.345967,0.327000,0.305667,0.276000,0.238283,0.200100,0.158817,0.107900,0.054817,0.000000,0.055767,0.110633,0.164067,0.213617,0.258733,0.299017,0.331467,0.356667,0.383183,0.401950,0.410967,0.417900,0.428933,0.436417,0.434783,0.430417]
#3.5sec
x_simulation_cycle_32_allsource_60k = [0.442533,0.437525,0.428892,0.424650,0.409017,0.381933,0.358442,0.339208,0.316142,0.283717,0.245083,0.206867,0.162358,0.110308,0.056850,0.000000,0.058108,0.114183,0.166550,0.215275,0.260033,0.301550,0.336033,0.360567,0.387492,0.408983,0.419842,0.428083,0.440792,0.449342,0.447717,0.443275]
#8sec
x_simulation_cycle_32_allsource_90k = [0.243907,0.241780,0.236526,0.235515,0.225523,0.208550,0.195392,0.184218,0.172959,0.155309,0.133176,0.113298,0.089148,0.060178,0.031247,0.000000,0.033302,0.065799,0.095058,0.122112,0.146566,0.169460,0.187372,0.199780,0.216009,0.228100,0.233121,0.237576,0.244846,0.248884,0.246484,0.243235]
x_simulation_cycle_32_allsource_90k = [2*i for i in x_simulation_cycle_32_allsource_90k]

x_simulation_cycle_32_allsource_120k = [0.238087,0.235733,0.230184,0.228277,0.218675,0.203025,0.190503,0.179531,0.167855,0.150314,0.128416,0.108546,0.085598,0.057960,0.030054,0.000000,0.031667,0.062583,0.091034,0.117277,0.141125,0.162969,0.180019,0.192724,0.208678,0.220787,0.226244,0.230813,0.237874,0.242277,0.240802,0.237803]
x_simulation_cycle_32_allsource_120k = [2*i for i in x_simulation_cycle_32_allsource_120k]
#12 sec
x_simulation_cycle_32_allsource_150k = [0.248384,0.246081,0.240729,0.239030,0.229462,0.213306,0.199880,0.188120,0.175250,0.155995,0.133454,0.113326,0.089066,0.060464,0.031478,0.000000,0.033181,0.065446,0.094618,0.121481,0.145968,0.168915,0.187853,0.200956,0.217269,0.230722,0.237027,0.241746,0.249197,0.254032,0.252066,0.248384]
x_simulation_cycle_32_allsource_150k = [2*i for i in x_simulation_cycle_32_allsource_150k]
#15 sec
x_simulation_cycle_32_allsource_180k = [0.245068,0.242774,0.237395,0.235884,0.226570,0.210616,0.197447,0.185964,0.173137,0.154131,0.131962,0.111862,0.087854,0.059890,0.031233,0.000000,0.032647,0.064197,0.092995,0.119663,0.143820,0.166503,0.185792,0.199344,0.214962,0.227859,0.234201,0.239067,0.246445,0.251022,0.249045,0.245143]
x_simulation_cycle_32_allsource_180k = [2*i for i in x_simulation_cycle_32_allsource_180k]
#17 sec
x_simulation_cycle_32_allsource_210k = [0.249545,0.247198,0.241547,0.239165,0.229677,0.214093,0.200744,0.188681,0.175318,0.155994,0.133681,0.113184,0.088619,0.060458,0.031542,0.000000,0.032810,0.064354,0.093168,0.120061,0.144176,0.166851,0.186534,0.200218,0.215995,0.229422,0.236277,0.241400,0.248967,0.254004,0.252602,0.249403,]
x_simulation_cycle_32_allsource_210k = [2*i for i in x_simulation_cycle_32_allsource_210k]

# %%
x_simulation_cycle_32_30k = [0.224074,0.233771,0.213810,0.198397,0.182001,0.165689,0.149410,0.131315,0.116119,0.101340,0.084211,0.067015,0.049953,0.032291,0.015946,0.000000,0.013646,0.027343,0.041072,0.053252,0.065799,0.080828,0.094825,0.109437,0.123167,0.134631,0.147577,0.162790,0.178552,0.190233,0.198630,0.210544]
x_simulation_cycle_32_60k = [0.227289,0.239120,0.218867,0.202913,0.186500,0.169330,0.152634,0.135356,0.120035,0.104405,0.086852,0.069390,0.052178,0.034249,0.016887,0.000000,0.013738,0.027684,0.041964,0.056093,0.070181,0.084377,0.097141,0.109912,0.123275,0.135064,0.147394,0.161982,0.177261,0.189791,0.199830,0.212427]
x_simulation_cycle_32_90k = [0.224229,0.235970,0.215809,0.200024,0.183196,0.165734,0.149016,0.133359,0.119557,0.103622,0.086044,0.069337,0.052186,0.034352,0.017029,0.000000,0.013552,0.027254,0.040922,0.054247,0.068021,0.082134,0.094869,0.107755,0.121812,0.134348,0.146094,0.159724,0.174987,0.187933,0.198064,0.209616]
x_simulation_cycle_32_120k = [0.221307,0.233298,0.212990,0.198603,0.181740,0.163074,0.146490,0.131482,0.118582,0.103303,0.085516,0.068883,0.051766,0.034037,0.016929,0.000000,0.013412,0.026921,0.040462,0.053650,0.067070,0.081070,0.093928,0.106703,0.120895,0.133199,0.144136,0.156711,0.171790,0.185073,0.195169,0.206202]
x_simulation_cycle_32_150k = [0.223697,0.235589,0.215217,0.200515,0.183456,0.164330,0.147561,0.132279,0.118866,0.103444,0.085492,0.068689,0.051284,0.033715,0.016959,0.000000,0.013569,0.027265,0.040831,0.054500,0.068356,0.082625,0.095828,0.108487,0.122716,0.135139,0.146348,0.159027,0.173833,0.187072,0.197315,0.208657]

# %%
plt.plot(list(range(0, len(x_sink_zero))), x_sink_zero, c = "blue", label= "Pyamg")
# plt.plot(list(range(0, len(x_simulation_cycle_32_30k))), x_simulation_cycle_32_30k, c = "red", label= "Lsolve30k")
# plt.plot(list(range(0, len(x_simulation_cycle_32_60k))), x_simulation_cycle_32_60k, c = "green", label= "Lsolve60k")
# plt.plot(list(range(0, len(x_simulation_cycle_32_90k))), x_simulation_cycle_32_90k, c = "cyan", label= "Lsolve90k")
# plt.plot(list(range(0, len(x_simulation_cycle_32_120k))), x_simulation_cycle_32_120k, c = "pink", label= "Lsolve120k")
# plt.plot(list(range(0, len(x_simulation_cycle_32_150k))), x_simulation_cycle_32_150k, c = "yellow", label= "Lsolve150k")
# plt.plot(list(range(0, len(x_simulation_cycle_32_180k))), x_simulation_cycle_32_180k, c = "magenta", label= "Lsolve180k")
# plt.plot(list(range(0, len(x_simulation_cycle_32_210k))), x_simulation_cycle_32_210k, c = "gray", label= "Lsolve180k")
 
    # To show the plot
plt.xlabel("x")
plt.ylabel("node")
plt.title("pyamg vs Lsolve")
plt.legend(loc ="lower left")
plt.savefig("pyamgvsLsolve_single_source.png")
# plt.close()

# %%
# Out:
# Details: Default AMG
# --------------------
# MultilevelSolver
# Number of Levels:     3
# Operator Complexity:  1.000
# Grid Complexity:      1.005
# Coarse Solver:        'pinv'
#   level   unknowns     nonzeros
#      0       14266      6766950 [99.98%]
#      1          65         1645 [0.02%]
#      2           4            9 [0.00%]
#
# The residual norm is 0.0014048335957854638

# %%
residual_x_sink_zero = b - a * x
residual_x_sink_zero[sink_index] = 0
plt.scatter(list(range(0, len(list(residual_x_sink_zero)))), list(residual_x_sink_zero), c = "blue")
 
    # To show the plot
plt.xlabel("residual")
plt.ylabel("node")
plt.title("f")
# print hierarchy information

print("The residual norm is {}".format(np.linalg.norm(residual_x_sink_zero)))  # compute norm of residual vector
# Out:
# The residual norm is 0.05000510147270793

# %%
print("\n")
print("The Multigrid Hierarchy")
print("-----------------------")
for l in range(len(ml.levels)):
    An = ml.levels[l].A.shape[0]
    Am = ml.levels[l].A.shape[1]
    if l == (len(ml.levels)-1):
        print(f"A_{l}: {An:>10}x{Am:<10}")
    else:
        Pn = ml.levels[l].P.shape[0]
        Pm = ml.levels[l].P.shape[1]
        print(f"A_{l}: {An:>10}x{Am:<10}   P_{l}: {Pn:>10}x{Pm:<10}")
# Out:
# The Multigrid Hierarchy
# -----------------------
# A_0:       1024x1024         P_0:       1024x1
# A_1:          1x1

# %%
X, Y = np.meshgrid(np.linspace(0, 1, dimension), np.linspace(0, 1, dimension))

# %%
ml = pyamg.smoothed_aggregation_solver(a,  # the matrix
                                       B=X.reshape(dimension * dimension, 1),             # the representation of the near null space (this is a poor choice)
                                       BH=None,                           # the representation of the left near null space
                                       symmetry='hermitian',              # indicate that the matrix is Hermitian
                                       strength='evolution',              # change the strength of connection
                                       aggregate='standard',              # use a standard aggregation method
                                       smooth=('jacobi', {'omega': 4.0 / 3.0, 'degree': 2}),   # prolongation smoothing
                                       presmoother=('block_gauss_seidel', {'sweep': 'symmetric'}),
                                       postsmoother=('block_gauss_seidel', {'sweep': 'symmetric'}),
                                       improve_candidates=[('block_gauss_seidel',
                                                           {'sweep': 'symmetric', 'iterations': 4}), None],
                                       max_levels=10,                     # maximum number of levels
                                       max_coarse=5,                      # maximum number on a coarse level
                                       keep=False)                        # keep extra operators around in the hierarchy (memory)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 ml = pyamg.smoothed_aggregation_solver(a,  # the matrix
#       2                                        B=X.reshape(dimension * dimension, 1),             # the representation of the near null space (this is a poor choice)
#       3                                        BH=None,                           # the representation of the left near null space
#       4                                        symmetry='hermitian',              # indicate that the matrix is Hermitian
#       5                                        strength='evolution',              # change the strength of connection
#       6                                        aggregate='standard',              # use a standard aggregation method
#       7                                        smooth=('jacobi', {'omega': 4.0 / 3.0, 'degree': 2}),   # prolongation smoothing
#       8                                        presmoother=('block_gauss_seidel', {'sweep': 'symmetric'}),
#       9                                        postsmoother=('block_gauss_seidel', {'sweep': 'symmetric'}),
#      10                                        improve_candidates=[('block_gauss_seidel',
#      11                                                            {'sweep': 'symmetric', 'iterations': 4}), None],
#      12                                        max_levels=10,                     # maximum number of levels
#      13                                        max_coarse=5,                      # maximum number on a coarse level
#      14                                        keep=False)                        # keep extra operators around in the hierarchy (memory)
#
# File ~/anaconda3/envs/pyamg/lib/python3.9/site-packages/pyamg/aggregation/aggregation.py:239, in smoothed_aggregation_solver(A, B, BH, symmetry, strength, aggregate, smooth, presmoother, postsmoother, improve_candidates, max_levels, max_coarse, diagonal_dominance, keep, **kwargs)
#     237     B = B.reshape(-1, 1)
#     238 if B.shape[0] != A.shape[0]:
# --> 239     raise ValueError('The shape of near null-space modes B is incorrect')
#     240 if B.shape[1] < get_blocksize(A):
#     241     warn('Having less target vectors, B.shape[1], than blocksize of A '
#     242          'can degrade convergence factors.')
#
# ValueError: The shape of near null-space modes B is incorrect

# %%
--------------------------------------------------------------------------------------

# %%
# ------------------------------------------------------------------
# Step 4: solve the system
# ------------------------------------------------------------------
res1 = []
x = ml.solve(b, tol=1e-12, residuals=res1)  # solve Ax=b to a tolerance of 1e-12
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_13723/2312312397.py", line 5, in <cell line: 5>
#     x = ml.solve(b, tol=1e-12, residuals=res1)  # solve Ax=b to a tolerance of 1e-12
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/pyamg/multilevel.py", line 465, in solve
#     residuals.append(residual_norm(A, x, b))
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/pyamg/util/linalg.py", line 108, in residual_norm
#     return norm(np.ravel(b) - A*np.ravel(x))
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/scipy/sparse/base.py", line 498, in __mul__
# ValueError: dimension mismatch
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/stack_data/core.py", line 720, in lines
#     pieces = self.included_pieces
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/stack_data/core.py", line 667, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/stack_data/core.py", line 646, in executing_piece
#     return only(
#   File "/home/sumaiya/anaconda3/envs/pyamg/lib/python3.9/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# ------------------------------------------------------------------
# Step 5: print details
# ------------------------------------------------------------------
print("\n")
print("Details: Default AMG")
print("--------------------")
print(ml)                                 # print hierarchy information

print("The residual norm is {}".format(np.linalg.norm(b - A * x)))  # compute norm of residual vector
# Out:
# Details: Default AMG
# --------------------
# multilevel_solver
# Number of Levels:     5
# Operator Complexity:  1.125
# Grid Complexity:      1.127
# Coarse Solver:        'pinv2'
#   level   unknowns     nonzeros
#     0        40000       357604 [88.91%]
#     1         4489        39601 [ 9.85%]
#     2          529         4489 [ 1.12%]
#     3           64          484 [ 0.12%]
#     4            9           49 [ 0.01%]
#
# The residual norm is 0.1440784341301821

# %%
# notice that there are 5 (or maybe 6) levels in the hierarchy
#
# we can look at the data in each of the levels
# e.g. the multigrid components on the finest (0) level
#      A: operator on level 0
#      P: prolongation operator mapping from level 1 to level 0
#      R: restriction operator mapping from level 0 to level 1
#      B: near null-space modes for level 0
#      presmoother: presmoothing function taking arguments (A,x,b)
#      postsmoother: postsmoothing function taking arguments (A,x,b)
print("\n")
print("The Multigrid Hierarchy")
print("-----------------------")
for l in range(len(ml.levels)):
    An = ml.levels[l].A.shape[0]
    Am = ml.levels[l].A.shape[1]
    if l == (len(ml.levels)-1):
        print(f"A_{l}: {An:>10}x{Am:<10}")
    else:
        Pn = ml.levels[l].P.shape[0]
        Pm = ml.levels[l].P.shape[1]
        print(f"A_{l}: {An:>10}x{Am:<10}   P_{l}: {Pn:>10}x{Pm:<10}")

# %%
# ------------------------------------------------------------------
# Step 6: change the hierarchy
# ------------------------------------------------------------------
# we can also change the details of the hierarchy
ml = pyamg.smoothed_aggregation_solver(A,  # the matrix
                                       B=X.reshape(n * n, 1),             # the representation of the near null space (this is a poor choice)
                                       BH=None,                           # the representation of the left near null space
                                       symmetry='hermitian',              # indicate that the matrix is Hermitian
                                       strength='evolution',              # change the strength of connection
                                       aggregate='standard',              # use a standard aggregation method
                                       smooth=('jacobi', {'omega': 4.0 / 3.0, 'degree': 2}),   # prolongation smoothing
                                       presmoother=('block_gauss_seidel', {'sweep': 'symmetric'}),
                                       postsmoother=('block_gauss_seidel', {'sweep': 'symmetric'}),
                                       improve_candidates=[('block_gauss_seidel',
                                                           {'sweep': 'symmetric', 'iterations': 4}), None],
                                       max_levels=10,                     # maximum number of levels
                                       max_coarse=5,                      # maximum number on a coarse level
                                       keep=False)                        # keep extra operators around in the hierarchy (memory)

# %%
# ------------------------------------------------------------------
# Step 7: print details
# ------------------------------------------------------------------
res2 = []                                               # keep the residual history in the solve
x = ml.solve(b, tol=1e-12, residuals=res2)              # solve Ax=b to a tolerance of 1e-12
print("\n")
print("Details: Specialized AMG")
print("------------------------")
print(ml)                                               # print hierarchy information
print("The residual norm is {}".format(np.linalg.norm(b - A * x)))  # compute norm of residual vector
print("\n")

# %%
# ------------------------------------------------------------------
# Step 8: plot convergence history
# ------------------------------------------------------------------
fig, ax = plt.subplots()
ax.semilogy(res1, label='Default AMG solver')
ax.semilogy(res2, label='Specialized AMG solver')
ax.set_xlabel('Iteration')
ax.set_ylabel('Relative Residual')
ax.grid(True)
plt.legend()

figname = f'./output/amg_convergence.png'
import sys
if '--savefig' in sys.argv:
    plt.savefig(figname, bbox_inches='tight', dpi=150)
else:
    plt.show()
# Out:
# The Multigrid Hierarchy
# -----------------------
# A_0:      40000x40000        P_0:      40000x6700
# A_1:       6700x6700         P_1:       6700x1237
# A_2:       1237x1237         P_2:       1237x109
# A_3:        109x109          P_3:        109x11
# A_4:         11x11           P_4:         11x4
# A_5:          4x4
#
#
# Details: Specialized AMG
# ------------------------
# multilevel_solver
# Number of Levels:     6
# Operator Complexity:  2.159
# Grid Complexity:      1.201
# Coarse Solver:        'pinv2'
#   level   unknowns     nonzeros
#     0        40000       357604 [46.31%]
#     1         6700       226352 [29.31%]
#     2         1232       176222 [22.82%]
#     3          109        11827 [ 1.53%]
#     4           13          169 [ 0.02%]
#     5            4           16 [ 0.00%]
#
# The residual norm is 1.0472786878774423e-10
