# %%
# Read all

# time_solver_beta = 
# residual_solver_beta = 

# create one list for residual per solver
# create one list for time per solver

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
import pylab as plb
plb.rcParams['font.size'] = 16

# %%
cmg_time = []
pyamg_time = []
chol_time = []
Kyng_Sach_time = []
Lsolve_time = []

cmg_residual = []
pyamg_residual = []
chol_residual = []
Kyng_Sach_residual = []
Lsolve_residual = []

f_chol = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b50_Chol_23"
f = open(f_chol, "r")
line = f.readline()
chol_time.append(float(line.split()[0]))
line = f.readline()
chol_residual.append(float(line.split()[0]))
f.close;

f_chol = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b25_Chol_23"
f = open(f_chol, "r")
line = f.readline()
chol_time.append(float(line.split()[0]))
line = f.readline()
chol_residual.append(float(line.split()[0]))
f.close;

f_chol = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b12_Chol_23"
f = open(f_chol, "r")
line = f.readline()
chol_time.append(float(line.split()[0]))
line = f.readline()
chol_residual.append(float(line.split()[0]))
f.close;
# end of chol read

f_cmg = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b50_CMG"
f = open(f_cmg, "r")
line = f.readline()
cmg_time.append(float(line.split()[0]))
line = f.readline()
cmg_residual.append(float(line.split()[0]))
f.close;

f_cmg = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b25_CMG"
f = open(f_cmg, "r")
line = f.readline()
cmg_time.append(float(line.split()[0]))
line = f.readline()
cmg_residual.append(float(line.split()[0]))
f.close;

f_cmg = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b12_CMG"
f = open(f_cmg, "r")
line = f.readline()
cmg_time.append(float(line.split()[0]))
line = f.readline()
cmg_residual.append(float(line.split()[0]))
f.close;

#reading of cmg done
f_pyamg = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b50_pyamg"
f = open(f_pyamg, "r")
line = f.readline()
pyamg_time.append(float(line.split()[0]))
line = f.readline()
pyamg_residual.append(float(line.split()[0]))
f.close;

f_pyamg = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b25_pyamg"
f = open(f_pyamg, "r")
line = f.readline()
pyamg_time.append(float(line.split()[0]))
line = f.readline()
pyamg_residual.append(float(line.split()[0]))
f.close;

f_pyamg = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b12_pyamg"
f = open(f_pyamg, "r")
line = f.readline()
pyamg_time.append(float(line.split()[0]))
line = f.readline()
pyamg_residual.append(float(line.split()[0]))
f.close;
pyamg_time

#reading of pyamg done

f_Kyng_Sach = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b50_Kyng_Sach"
f = open(f_Kyng_Sach, "r")
line = f.readline()
Kyng_Sach_time.append(float(line.split()[0]))
line = f.readline()
Kyng_Sach_residual.append(float(line.split()[0]))
f.close;

f_Kyng_Sach = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b25_Kyng_Sach"
f = open(f_Kyng_Sach, "r")
line = f.readline()
Kyng_Sach_time.append(float(line.split()[0]))
line = f.readline()
Kyng_Sach_residual.append(float(line.split()[0]))
f.close;

f_Kyng_Sach = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b12_Kyng_Sach"
f = open(f_Kyng_Sach, "r")
line = f.readline()
Kyng_Sach_time.append(float(line.split()[0]))
line = f.readline()
Kyng_Sach_residual.append(float(line.split()[0]))
f.close;

#  readin gof kyng sach done

f_Lsolve = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b50_Lsolve"
f = open(f_Lsolve, "r")
line = f.readline()
Lsolve_time.append(float(line.split()[0]))
line = f.readline()
Lsolve_residual.append(float(line.split()[0]))
f.close;

f_Lsolve = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b25_Lsolve"
f = open(f_Lsolve, "r")
line = f.readline()
Lsolve_time.append(float(line.split()[0]))
line = f.readline()
Lsolve_residual.append(float(line.split()[0]))
f.close;

f_Lsolve = "/home/sumaiya/Desktop/Datasets/julia_solvers/wiki_bug/results/final_results/b12_Lsolve"
f = open(f_Lsolve, "r")
line = f.readline()
Lsolve_time.append(float(line.split()[0]))
line = f.readline()
Lsolve_residual.append(float(line.split()[0]))
f.close;
Lsolve_time
# Out:
# [76.4053, 73.1815, 59.1547]

# %%
chol_time = [2.0452370643615723, 1.9321210384368896 ,2.0123140811920166 ]
pyamg_time = [0.9109692573547363, 0.8991415500640869 ,0.9835560321807861 ]
cmg_time = [3.3164641857147217 , 3.219517946243286 ,3.2711238861083984 ]
Kyng_Sach_time = [3.0973429679870605 ,2.7633090019226074 ,3.1145660877227783 ]
Lsolve_time = [7.04622 ,7.04463,6.63094 ]
Lsolve_time2N = [14.3318, 14.2475, 13.5414]

# %%
# Plot time
X = ['50','25','12.5']

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, chol_time, 0.09, label = 'Chol23')
plt.bar(X_axis - 0.1, pyamg_time, 0.09, label = 'PyAMG23')
plt.bar(X_axis + 0.00, cmg_time, 0.09, label = 'CMG20')
plt.bar(X_axis + 0.1, Kyng_Sach_time, 0.09, label = 'Kyng16')
plt.bar(X_axis + 0.2, Lsolve_time, 0.09, label = 'Lsolve23')
  
plt.xticks(X_axis, X)
plt.xlabel("Percetage of source nodes") #increase size
plt.ylabel("Execution time (in sec)")
plt.title("Execution time comparision")
plt.legend(prop = { "size": 8 })
plt.show()

# %%
chol_residual = [1.8853179121137114e-13 ,

8.227403628063061e-14 ,

7.536659793463184e-14 ]
pyamg_residual = [0.0014805468858183192 ,

0.001442950978483732, 

0.0013609615438787623 ]
cmg_residual = [0.0027732175203496793 ,

0.002687444324380996 ,

0.002751820107462751 ]
Kyng_Sach_residual = [0.01471455039760366 ,

0.013963631864872164 ,

0.01609694520747011 ]
Lsolve_residual = [0.015434798102794984  ,0.016272954529966306 ,0.009877172999110501  ]
Lsolve_residual2N = [0.012610901188661422, 0.012335972493355028, 0.007579146378236276]

# %%
# Plot residual
X = ['50','25','12.5']

X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, chol_residual, 0.09, label = 'Chol23')
plt.bar(X_axis - 0.1, pyamg_residual, 0.09, label = 'PyAMG23')
plt.bar(X_axis + 0.00, cmg_residual, 0.09, label = 'CMG20')
plt.bar(X_axis + 0.1, Kyng_Sach_residual, 0.09, label = 'Kyng16')
plt.bar(X_axis + 0.2, Lsolve_residual, 0.09, label = 'Lsolve23')
  
plt.xticks(X_axis, X)
plt.xlabel("Percetage of source nodes") #increase size
plt.ylabel("Residual (|Lx-b|)")
plt.title("Residual comparision")
plt.legend(prop = { "size": 8 })
plt.show()
